# %% [markdown]
# ## Python_Comments Notebook:

# %% [markdown]
# ### Definition:
# Comments and it's Uses: A text written in a program to explain what code does, and it is ignore when executing the program. It's Uses;

# %% [markdown]
# ### It's Uses:
# 1. To Explain code
# 2. To make code easier to understand
# 3. To document important inforamtion
# 4. To temporarily disable code
# 5. To separate sections of program

# %%
# Example: 
# ---------------
# information
# ---------------
name = "Yubaraj"
age = 24
# ----------------
# Display information
# -----------------
print (name)
print (age)
# Out:
# Yubaraj
# 24

# %% [markdown]
# ### Single line Comments:

# %%
# Example:
# This is single line comments
print ("Hello Mann")
# Out:
# Hello Mann

# %% [markdown]
# ### Multi line Comments:

# %%
# Example: 
# This program calculates 
# the area of rectangle
# using length and width. 
length = 20 
width = 15
area = length * width
print (area)
# Out:
# 300

# %%
###This program calculates 
 the area of rectangle
 using length and width.###
# Out:
#   Cell In [2], line 2
#     the area of rectangle
#     ^
# IndentationError: unexpected indent
